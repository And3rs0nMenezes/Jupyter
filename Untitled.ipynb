# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('housing.csv')
df.head()
print(df.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df_selected = df[['longitude', 'latitude', 'median_house_value', 'housing_median_age']]
print(df_selected.head())
# Out:
#    longitude  latitude  median_house_value  housing_median_age
# 0    -122.23     37.88            452600.0                41.0
# 1    -122.22     37.86            358500.0                21.0
# 2    -122.24     37.85            352100.0                52.0
# 3    -122.25     37.85            341300.0                52.0
# 4    -122.25     37.85            342200.0                52.0

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_selected)
print(df_scaled[:5])
# Out:
# [[-1.32783522  1.05254828  2.12963148  0.98214266  0.60952691]
#  [-1.32284391  1.04318455  1.31415614 -0.60701891  0.60952691]
#  [-1.33282653  1.03850269  1.25869341  1.85618152  0.60952691]
#  [-1.33781784  1.03850269  1.16510007  1.85618152  0.60952691]
#  [-1.33781784  1.03850269  1.17289952  1.85618152  0.60952691]]

# %%
wcss = []
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(df_scaled)
    wcss.append(kmeans.inertia_)
    print(wcss)
# Out:
# [50223.29892553532]
# [50223.29892553532, 40797.007749771816]
# [50223.29892553532, 40797.007749771816, 33289.628562009995]
# [50223.29892553532, 40797.007749771816, 33289.628562009995, 29323.78550149804]
# [50223.29892553532, 40797.007749771816, 33289.628562009995, 29323.78550149804, 21739.9514804614]
# [50223.29892553532, 40797.007749771816, 33289.628562009995, 29323.78550149804, 21739.9514804614, 20019.34908998809]
# [50223.29892553532, 40797.007749771816, 33289.628562009995, 29323.78550149804, 21739.9514804614, 20019.34908998809, 18347.899177368105]
# [50223.29892553532, 40797.007749771816, 33289.628562009995, 29323.78550149804, 21739.9514804614, 20019.34908998809, 18347.899177368105, 17008.366847819314]
# [50223.29892553532, 40797.007749771816, 33289.628562009995, 29323.78550149804, 21739.9514804614, 20019.34908998809, 18347.899177368105, 17008.366847819314, 15832.088520564528]

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(2, 11), wcss, marker='o')
plt.title('Método do Cotovelo')
plt.xlabel('Número de Clusters')
plt.ylabel('WCSS')
plt.grid(True)
plt.xticks(range(2, 11))
plt.show()
